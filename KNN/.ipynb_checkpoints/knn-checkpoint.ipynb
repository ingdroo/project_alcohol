# %%
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

#初始化變數
count = 0
count_2 = 0
main_list = []
target = []
X=[]
y=[]

#篩選酒癮的目標
ICD9_addtion = ["2919 ","2910 ","2911 ","2912 ","2913 ","2914 ","2915 ","29189","29181","303  ",\
        "30301","30302","30303","30390","30391","30392","30393","30500","30501","30502",\
        "30503","29190","29100","29110","29120","29130","29140","29150","30300"]
#避免誤差將所有有空格的部分添加0
#篩選併發症的目標
ICD9_complication = ["7882 ","1917 ","2511 ","2749 ","2762 ","291  ","292  ","2962 ","3019 ","3343 ","414  ","4255 ","4801 ","5563 ","5713 ","577  ","7159 ","72982","76071","984  "
,"78820","19170","25110","27490","27620","29100","29200","29620","30190","33430","41400","42550","48010","55630","57130","57700","71590","72982","76071","98400"]

#讀DD檔
f = open("/Users/xuboya/Desktop/2006cut.txt", "r")
#預測酒癮>>目標有無酒癮，0沒酒癮1有酒癮男性2有酒癮女性
#預測酒癮>>特徵icd有沒有20個酒癮帶馬，男性，女性，無關性別
for line in f:
    if count != 100 :
            #print(type(line))
            #特徵費用-年月=得出就診年齡
            fee_month = line[0:4]#只抓年特徵
            birth_date = line[40:44]#只抓年特徵 

            #ex:2021-2000
            age=int(fee_month)-int(birth_date)

                     
#看診3次，其中有一筆有酒癮代碼就去掉，但是這個人的其他資料會被保留下來，會把這個人所以偶資料變成target1
            main_result = line[52:57]   #特徵 主診
            sec1_result = line[58:63]   #特徵 次診1
            sec2_result = line[64:69]   #特徵 次診2
            sec3_result = line[70:75]   #特徵 次診3
            sec4_result = line[76:81]   #特徵 次診4

 

            if(line[82]=='Ｍ'):#特徵sex
                sex=1
            else:
                sex=0
            
            #五個裡面有找到酒癮的，如果都沒有找到就是0
            if main_list in ICD9_addtion :
                target += [1]
            elif sec1_result in ICD9_addtion :
                target += [1]
            elif sec2_result in ICD9_addtion :
                target += [1]
            elif sec3_result in ICD9_addtion :
                target += [1]
            elif sec4_result in ICD9_addtion :
                target += [1]
            else:
                target += [0]
            main_list = [main_result,sec1_result,sec2_result,sec3_result,sec4_result,age,sex]
              #--------------
           

            #特徵性別、年紀、診斷碼
            
            
                
            #X=[[sex,age,target[count]]]
          
            X+=[[sex,age]]
            y+=[[target[count]]]
            
            #X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

            if count<100 and target[count]==0:
                #print(X)
                #print(y)
                #print(line)
            #X.append()
            #X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)
           
                
           
            #X.append()
            #目標有無酒癮0 1



            


            #--------------
            
            #--------------



             #--------------
            
             count = count + 1
                
#轉型

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)#80 20 80 20
           
#訓練資料用在訓練模型的時候
#測試則用來測試看看這個模型預測的準確度
#資料分開成兩部分
#test_size=0.2代表0.2用來測試用，其餘0.8是來訓練電腦的            
#train_data , test_data , train_label , test_label = \
#train_test_split(iris_data, iris_label, test_size=0.2)
#KNeighbors分類法
#knn = KNeighborsClassifier()
           


#資料做訓練
#knn = KNeighborsClassifier()
#knn.fit(X_train, X_test)

knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)
pred = knn.predict(X_test)

from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))

#print(knn.predict(test_data))


#if 1 in target:
#    print('correct')
#else:
    #print('error')
f.close()
knn.score(X_test, y_test)
